# %% [markdown]
# # Results from a Single CTM Run with the ^BOUND^ Bound
# This describes the topic means, covariances, and perplexity of a single model run. The configuration of the model is given further below, after it has been loaded.

# %% [markdown]
# # Prelude

# %% [markdown]
# ## Configuration

# %%
import sys


codePath = "/Users/bryanfeeney/Workspace/sidetopics/src"

dataPathPrefix = "/Users/bryanfeeney/Desktop/Tweets600/"
wordsPath = dataPathPrefix + "words-noisy.pkl"
featsPath = dataPathPrefix + "side-noisy.pkl"
authsPath = dataPathPrefix + "words-by-author-all-in-one.pkl"

outputPathPrefix = "/Users/bryanfeeney/Desktop/k5_results/"
outputFiles = [ \
    outputPathPrefix + 'ctm_bohning_k_5_fold_0_20140225_1336.pkl', \
    outputPathPrefix + 'ctm_bohning_k_5_fold_1_20140225_1338.pkl', \
    outputPathPrefix + 'ctm_bohning_k_5_fold_2_20140225_1339.pkl', \
    outputPathPrefix + 'ctm_bohning_k_5_fold_3_20140225_1340.pkl', \
    outputPathPrefix + 'ctm_bohning_k_5_fold_4_20140225_1341.pkl' ]

#outputFiles = "^outputPath^"
FoldCount = len(outputFiles)
reconstructSparse=False

sys.path.append(codePath)
# %run /Users/bryanfeeney/Desktop/Tweets600/dicts.py
#%run ^dictPath^

# %% [markdown]
# ## Imports

# %%
import numpy as np
import numpy.random as rd
import scipy as sp
import scipy.sparse as ssp
import scipy.linalg as la
import scipy.sparse.linalg as sla
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import pickle as pkl

from math import log, pi, exp, ceil

rd.seed(0xC0FFEE)

# %load_ext cythonmagic
# %matplotlib inline

# %%
import model
from util.sigmoid_utils import rowwise_softmax
#from model.^algorclass^ import log_likelihood, perplexity, ModelState, QueryState
from model.ctm import log_likelihood, perplexity, ModelState, QueryState

# %% [markdown]
# ## Useful functions
# The main body of this is a function (```sparseScalarQuotientOfSafeLnDot()```) used to calculate the log-likelihood efficiently. It's written in Cython for performance reasons, hence the typing.

# %%
from IPython.display import HTML
from IPython.display import Latex
from IPython.display import Image

# %%
def normalize_rows_ip(matrix):
    '''
    Normalizes the rows of the matrix in-place, ovewriting
    the previous values
    '''
    row_sums  = matrix.sum(axis=1)
    matrix   /= row_sums[:, np.newaxis]
    return matrix

# %%
# %%cython
#
# cimport cython
# import numpy as np
# cimport numpy as np
# from libc.math cimport log
# from libc.float cimport FLT_MIN, DBL_MIN
#
# @cython.boundscheck(False)
# @cython.wraparound(False)
# @cython.cdivision(True)
# def sparseScalarProductOfSafeLnDot_f8(double[:] A_data, int[:] A_indices, int[:] A_ptr, double[:,:] B, double[:,:] C, double[:] out_data):
#     '''
#     Returns A * np.log(np.dot(B, C)), however it does so keeping in
#     mind the sparsity of A, calculate values only when required.
#     Moreover if any product of the dot is zero, it's replaced with
#     the minimum non-zero value allowed by the datatype, to avoid NaNs
#
#     Params
#     A_data    - the values buffer of the sparse CSR matrix A
#     A_indices - the indices buffer of the sparse CSR matrix A
#     A_ptr     - the index pointer buffer of the sparse CSR matrix A
#     B         - a dense matrix
#     C         - a dense matrix
#     out_data  - the values buffer into which the result will be placed.
#
#     Returns
#     out_data, though note that this is the same parameter passed in and overwitten.
#     '''
#     cdef:
#         int rowCount = len(A_ptr) - 1
#         int elemCount = 0, e = 0
#         int row = 0, col = 0, i = 0
#         double dotProd = 0.0
#         double logOfMin = log (DBL_MIN)
#
#     with nogil:
#         while row < rowCount:
#             elemCount = A_ptr[row+1] - A_ptr[row]
#             e = 0
#             while e < elemCount:
#                 col         = A_indices[i]
#                 dotProd     = dotProduct_f8(row,col,B,C)
#                 out_data[i] = A_data[i] * log(dotProd) if dotProd > DBL_MIN else logOfMin
#                 i += 1
#                 e += 1
#             row += 1
#
#     return out_data
#
# @cython.boundscheck(False)
# @cython.wraparound(False)
# @cython.cdivision(True)
# def sparseScalarProductOfSafeLnDot_f4(float[:] A_data, int[:] A_indices, int[:] A_ptr, float[:,:] B, float[:,:] C, float[:] out_data):
#     '''
#     Returns A * np.log(np.dot(B, C)), however it does so keeping in
#     mind the sparsity of A, calculate values only when required.
#     Moreover if any product of the dot is zero, it's replaced with
#     the minimum non-zero value allowed by the datatype, to avoid NaNs
#
#     Params
#     A_data    - the values buffer of the sparse CSR matrix A
#     A_indices - the indices buffer of the sparse CSR matrix A
#     A_ptr     - the index pointer buffer of the sparse CSR matrix A
#     B         - a dense matrix
#     C         - a dense matrix
#     out_data  - the values buffer into which the result will be placed.
#
#     Returns
#     out_data, though note that this is the same parameter passed in and overwitten.
#     '''
#     cdef:
#         int rowCount = len(A_ptr) - 1
#         int elemCount = 0, e = 0
#         int row = 0, col = 0, i = 0
#         float dotProd = 0.0
#         float logOfMin = log (FLT_MIN)
#
#     with nogil:
#         while row < rowCount:
#             elemCount = A_ptr[row+1] - A_ptr[row]
#             e = 0
#             while e < elemCount:
#                 col         = A_indices[i]
#                 dotProd     = dotProduct_f4(row,col,B,C)
#                 out_data[i] = A_data[i] * log(dotProd) if dotProd > FLT_MIN else logOfMin
#                 i += 1
#                 e += 1
#             row += 1
#
#     return out_data
#
# @cython.boundscheck(False)
# @cython.wraparound(False)
# @cython.cdivision(True)
# cdef double dotProduct_f8 (int r, int c, double[:,:] B, double[:,:] C) nogil:
#     '''
#     The dot product of the r-th row of B and the c-th column of C.
#     Done directly with a for-loop, no BLAS, SSE or anything. Still
#     pretty fast though - just as quick as a numpy dot
#     '''
#
#     cdef double result = 0
#     cdef int innerDim = B.shape[1]
#
#     cdef int i = 0
#     while i < innerDim:
#         result += B[r,i] * C[i,c]
#         i += 1
#
#     return result
#
#
# @cython.boundscheck(False)
# @cython.wraparound(False)
# @cython.cdivision(True)
# cdef float dotProduct_f4 (int r, int c, float[:,:] B, float[:,:] C) nogil:
#     '''
#     The dot product of the r-th row of B and the c-th column of C.
#     Done directly with a for-loop, no BLAS, SSE or anything. Still
#     pretty fast though - just as quick as a numpy dot
#     '''
#     cdef float result = 0
#     cdef int innerDim = B.shape[1]
#
#     cdef int i = 0
#     while i < innerDim:
#         result += B[r,i] * C[i,c]
#         i += 1
#
#     return result

# %%
def sparseScalarProductOfSafeLnDot (A, B, C, out=None):
    '''
    Returns A * np.log(np.dot(B, C)), however it does so keeping in
    mind the sparsity of A, calculating values only where required.
    Moreover if any product of the dot is zero, it's replaced with
    the minimum non-zero value allowed by the datatype, to avoid NaNs
     
    Params
    A         - a sparse CSR matrix
    B         - a dense matrix
    C         - a dense matrix
    out       - if specified, must be a sparse CSR matrix with identical
                non-zero pattern to A (i.e. same indices and indptr)
    
    Returns
    out_data, though note that this is the same parameter passed in and overwitten.
    '''
    if out is None:
        out = A.copy()
    if A.dtype == np.float64:
        sparseScalarProductOfSafeLnDot_f8(A.data, A.indices, A.indptr, B, C, out.data)
    elif A.dtype == np.float32:
        sparseScalarProductOfSafeLnDot_f4(A.data, A.indices, A.indptr, B, C, out.data)
    
    return out

# %% [markdown]
# # Model Results

# %% [markdown]
# ## Load the Model

# %%
orders      = []
boundItrs   = []
boundVals   = []
model       = []
trainTopics = []
queryTopics = []

for outputFile in outputFiles:
    with open(outputFile, "rb") as f:
        (o, i, v, m, t, q) = pkl.load(f)
        orders.append(o)
        boundItrs.append(i)
        boundVals.append(v)
        model.append(m)
        trainTopics.append(t)
        queryTopics.append(q)

# %% [markdown]
# Determine if the model executed successfully. We expect to have __five__ completed folds, with associated model configurations.

# %%
successfulQueryCount = 0
for queryTopic in queryTopics:
    if queryTopic is not None:
        successfulQueryCount += 1

# %%
if successfulQueryCount < FoldCount:
    h = HTML("<h1><font color='red'>Training Run Failed to Complete</font></h1>")
else:
    h = HTML("<font color='green'>Training Completed Successfully</font>")
h
# Out:
# <font color='green'>Training Completed Successfully</font>

# %%
# It makes no sense to continue if we don't have many queries
if successfulQueryCount < FoldCount:
    exit(-1)

# %% [markdown]
# ## Model Configuration

# %%
model[0].name
# Out:
# 'ctm/bohning'

# %%
# Number of topics
model[0].K
# Out:
# 5

# %%
# Size of Latent Space
if model[0].name[:3] == 'stm':
    model[0].P

# %% [markdown]
# ### Evolution of the Variational Bound During Training
# I'm still not sure why there's a dip in the first few iterations. The updates which cause a dip are the vocabularly and the posterior means. Note the extremely large number of iterations, in the past with, e.g. LDA, CTM/Bouchard, I've only ever needed a few hundred iterations before things levelled off.

# %%
colCount = 2
rowCount = int(ceil (FoldCount / colCount))

fig, ax = plt.subplots(rowCount, colCount, figsize=(11,9))
for fold in range(FoldCount):
    row = fold // colCount
    col = fold % colCount
    
    ax[row,col].plot(boundItrs[0], boundVals[0])
    ax[row,col].set_title("Fold-" + str(fold))
fig.suptitle("Variational Bound")

# %% [markdown]
# ## Load the Data

# %%
# We assume the order is always the same (order refers to the order the data
# was presented to the cross-val train and test algorithm: we shuffle the 
# data before creating the cross-validated slices)
order = orders[0]
if model[0].name[:3] == 'ctm':
    with open(authsPath, 'rb') as f:
        (userLabels, dic, W)  = pkl.load(f)
        W = W[order,:].astype(model[0].dtype)
    
    X = None
else:
    with open(wordsPath, 'rb') as f:
        W = pkl.load(f)
        W = W[order,:].astype(model[0].dtype)
    with open(featsPath, 'rb') as f:
        X = pkl.load(f)
        X = X[order,:].astype(model[0].dtype)
        
    uidMatrix = X[feats['author'],:].todense()
    uids = np.squeeze(np.asarray(np.argmax(uidMatrix, axis=1)))
    userLabels = [users[uid] for uid in uids]

# %%
D,T = W.shape
F = 0 if X is None else X.shape[1]

# %% [markdown]
# ## Output of the Model on the Data

# %% [markdown]
# ### Log Likelihood and Perplexity

# %%
from run.main import splitInput

# %%
foldSize  = ceil(D / FoldCount)
querySize = foldSize
trainSize = D - querySize
        
print ("Fold ID \t %-30s \t %-20s" % ('Log Likelihood', 'Perplexity'))
for fold in range(FoldCount):
    start = fold * foldSize
    end   = start + trainSize
    
    trainSet = np.arange(start,end) % D
    querySet = np.arange(end, end + querySize) % D
    
    W_train, W_query = W[trainSet,:], W[querySet,:]
    W_query_train, W_query_eval = splitInput(X, W_query)
    
    logLikely = np.sum( \
        sparseScalarProductOfSafeLnDot(\
            W_query_eval, \
            rowwise_softmax(queryTopics[fold].means), \
            model[fold].vocab \
        ).data \
    )
    
    perplexity = np.exp(-logLikely / np.sum(W_query_eval.data))
    print ("Fold %2d \t %30.3f \t %20.2f" % (fold, logLikely, perplexity))
# Out:
# Fold ID 	 Log Likelihood                 	 Perplexity
# Fold  0 	                   -4046654.250 	              4885.48
# Fold  1 	                   -4908111.000 	              4310.48
# Fold  2 	                   -5273680.000 	              7236.96
# Fold  3 	                   -5840521.500 	              5423.58
# Fold  4 	                   -4538678.500 	              6054.86

# %% [markdown]
# ## Topics for Fold-4
# Print the top words for each topic. How many words is specified by the ```topWordCount``` variable. For simplicity we only consider the final fold here.

# %%
topWordCount=30
fold = 4
W_fold = W_train

# %%
# Based on corpus-wide term distribution
counts = W_fold.sum(axis = 0)
freq = counts / counts.sum()
freq = np.squeeze(np.asarray(freq))
freq += 1E-35 if counts.dtype == np.float32 else 1E-300

denom = (1 + freq)

# %%
#scale = 1
scale = np.reciprocal(denom)

# %%
def topWordInds (wordDict, vocab, count=10):
    return vocab.argsort()[-count:][::-1]

kTopWordsIdf = [topWordInds(dic, model[fold].vocab[k,:] * scale, count=topWordCount) \
                for k in range(model[fold].K)]

# %%
for k in range(model[fold].K):
    print ("\n\nTopic " + str(k) + "\n================================")
    for c in range(topWordCount):
        print ("%-30s %05.4f" % (dic[kTopWordsIdf[k][c]], model[fold].vocab[k][kTopWordsIdf[k][c]]))
# Out:
# Topic 0
# ================================
# you                            0.0160
# so                             0.0092
# just                           0.0091
# have                           0.0089
# he                             0.0085
# like                           0.0081
# my                             0.0080
# it                             0.0074
# me                             0.0070
# i'm                            0.0068
# she                            0.0062
# what                           0.0060
# :)                             0.0059
# go                             0.0055
# all                            0.0055
# get                            0.0054
# do                             0.0053
# think                          0.0048
# don't                          0.0048
# about                          0.0047
# ha                             0.0047
# on                             0.0045
# her                            0.0044
# up                             0.0043
# out                            0.0042
# good                           0.0041
# know                           0.0040
# now                            0.0039
# time                           0.0039
# see                            0.0039
#
#
# Topic 1
# ================================
# set                            0.0148
# match                          0.0084
# win                            0.0083
# plai                           0.0073
# he                             0.0073
# break                          0.0066
# from                           0.0065
# ha                             0.0064
# up                             0.0061
# first                          0.0061
# hi                             0.0056
# get                            0.0056
# #usopen                        0.0054
# her                            0.0051
# final                          0.0051
# serena                         0.0050
# serv                           0.0050
# now                            0.0049
# game                           0.0049
# open                           0.0048
# out                            0.0048
# #wimbledon                     0.0047
# point                          0.0046
# have                           0.0046
# nadal                          0.0043
# she                            0.0043
# #rg13                          0.0042
# just                           0.0040
# seed                           0.0039
# vs                             0.0039
#
#
# Topic 2
# ================================
# you                            0.0245
# have                           0.0082
# thank                          0.0080
# we                             0.0079
# my                             0.0077
# your                           0.0076
# so                             0.0062
# out                            0.0061
# from                           0.0057
# all                            0.0055
# it                             0.0055
# get                            0.0053
# our                            0.0051
# us                             0.0051
# just                           0.0050
# what                           0.0050
# do                             0.0050
# go                             0.0050
# love                           0.0050
# new                            0.0048
# up                             0.0047
# good                           0.0047
# me                             0.0047
# on                             0.0046
# like                           0.0044
# dai                            0.0043
# now                            0.0042
# look                           0.0041
# great                          0.0041
# about                          0.0040
#
#
# Topic 3
# ================================
# obama                          0.0073
# new                            0.0070
# from                           0.0052
# game                           0.0045
# vs                             0.0040
# sai                            0.0037
# et                             0.0036
# stat                           0.0035
# us                             0.0035
# about                          0.0035
# sheet                          0.0034
# out                            0.0034
# b-r                            0.0032
# gop                            0.0032
# more                           0.0031
# bill                           0.0028
# year                           0.0027
# report                         0.0027
# state                          0.0027
# over                           0.0027
# senat                          0.0027
# up                             0.0027
# hous                           0.0026
# how                            0.0025
# after                          0.0025
# via                            0.0024
# market                         0.0024
# bank                           0.0024
# women                          0.0023
# get                            0.0023
#
#
# Topic 4
# ================================
# you                            0.0325
# have                           0.0138
# sorri                          0.0088
# my                             0.0085
# can                            0.0079
# we                             0.0079
# your                           0.0077
# so                             0.0076
# thank                          0.0073
# what                           0.0068
# just                           0.0068
# hi                             0.0066
# do                             0.0066
# me                             0.0064
# about                          0.0064
# it                             0.0062
# like                           0.0062
# get                            0.0055
# i'm                            0.0051
# olli                           0.0050
# all                            0.0049
# good                           0.0049
# know                           0.0048
# on                             0.0047
# train                          0.0045
# servic                         0.0043
# us                             0.0043
# time                           0.0042
# think                          0.0041
# ha                             0.0041

# %% [markdown]
# ## Topic Assignments in Fold-4

# %%
dist = rowwise_softmax(trainTopics[fold].means)
distMean = dist.mean(axis=0)

queryDist = rowwise_softmax(queryTopics[fold].means)
queryDistMean = dist.mean(axis=0)

# %% [markdown]
# ### Means

# %%
fig, ax = plt.subplots(figsize=(10,3))

im = plt.imshow(distMean.reshape((1, len(distMean))), interpolation="none")

cb = fig.colorbar(im, ax=ax)
ax.set_title("Mean of Posterior Means (Training)")

# %%
# As integer percentages for readability
(distMean * 100).astype(np.int32)
# Out:
# array([17,  7, 40, 18, 15], dtype=int32)

# %%
fig, ax = plt.subplots(figsize=(10,3))

im = plt.imshow(queryDistMean.reshape((1, len(distMean))), interpolation="none")

cb = fig.colorbar(im, ax=ax)
ax.set_title("Mean of Posterior Means (Query)")

# %%
# As integer percentages for readability
(queryDistMean * 100).astype(np.int32)
# Out:
# array([17,  7, 40, 18, 15], dtype=int32)

# %% [markdown]
# ### Covariance

# %%
fig, ax = plt.subplots(figsize=(11,9))

im = plt.imshow(model[fold].sigT, interpolation="none")

cb = fig.colorbar(im, ax=ax)
ax.set_title("Covariance Matrix")

# %% [markdown]
# ### Mapping Tweeters to Topics

# %%
if type(X) == ssp.csr_matrix:
    X = X.todense() # Needs to be dense for searching. Fortunately not huge like W

# %%
userLabels
# Out:
# ['ACLU',
#  'AdvocatesTweets',
#  'AnnRichardsPlay',
#  'AskDrRuth',
#  'BabatundeUNFPA',
#  'Beyerstein',
#  'CLPPtweets',
#  'CecileRichards',
#  'ChrisCQuinn',
#  'ChrisCoons',
#  'ChrisMurphyCT',
#  'ConnieSchultz',
#  'CraryAP',
#  'DemGovs',
#  'DrNancyNBCNEWS',
#  'ElizabethBanks',
#  'ErinMcPike',
#  'ForbesWoman',
#  'FriendsofUNFPA',
#  'GOPChoice',
#  'GovMarkDayton',
#  'Guttmacher',
#  'HealthCareGov',
#  'HollandTaylor',
#  'HuffPostPol',
#  'IpasOrg',
#  'JessicaValenti',
#  'KofiAnnan',
#  'LatinoUSA',
#  'Latinos4PP',
#  'MHarrisPerry',
#  'MaryKayHenry',
#  'MoreMag',
#  'NARAL',
#  'HadleyFreeman',
#  'benschott',
#  '247WallSt',
#  '4Tanguay',
#  '5280Magazine',
#  '5_min_macro',
#  'ABWashBureau',
#  'APStylebook',
#  'A_F',
#  'Aalliende',
#  'AcrossTheCurve',
#  'AlexAkesson',
#  'AmazonKDP',
#  'AndyHarless',
#  'AndyLangenkamp',
#  'AnnalynKurtz',
#  'AristidesHatzis',
#  'BChappatta',
#  'BDAmerica',
#  'BIConline',
#  'Bank_of_Japan_e',
#  'Benzinga',
#  'BergenCapital',
#  'BigJournalism',
#  'BlackRaven999',
#  'Blackhorse',
#  'EvelynRusli',
#  'Tim_Stevens',
#  'gte',
#  'DirtyWars',
#  'RollingStones',
#  'FilmCritHULK',
#  'Gary_Bainbridge',
#  '3RiversBrewery',
#  '4pawsbrewing',
#  'AGonzalezAquino',
#  'AbbeyStMartin',
#  'AlmanacBeer',
#  'AnarchyBrewCo',
#  'AnchorBrewing',
#  'ArgusBrewery',
#  'ArranBrewery',
#  'AtlasBrewing',
#  'BHB_brews',
#  'BeerAdvocate',
#  'BeerAndSoulBlog',
#  'BeerBods',
#  'BeerUnion',
#  'Beer_Disciples',
#  'Beer_Goddess',
#  'BeersIveKnown',
#  'Beertographer',
#  'Bierschenke',
#  'BlueBellHalkyn',
#  'BluffersGuide',
#  'BreckBrew',
#  'BrewDogBarDean',
#  'BrewEngland',
#  'Brewery85',
#  'BrianIsBeering',
#  'BubOhioBeer',
#  'BullCityBurger',
#  'ButcombeBrewery',
#  'ConistonBrewCo',
#  'CraftingANation',
#  'CromartyBrewing',
#  'DFDband',
#  'DailyBeerNews',
#  'Dryhopchicago',
#  'DueSouthBrewing',
#  'DukesJoint',
#  'EHobbz',
#  'EasyTigerATX',
#  'FGW',
#  'FallCreekWines',
#  'FiremansBrew',
#  'FirestoneWalker',
#  'ForumBooks',
#  'FullCircleBrews',
#  'GarrisonBrewing',
#  'Goats_Udder',
#  'Gordon_Biersch',
#  '3_News',
#  'AbiePB',
#  'Amanda_Statham',
#  'AmyDavies',
#  'Arganic_UK',
#  'Ayngelina',
#  'BBCGoodFoodShow',
#  'Bea_John',
#  'Beergenie',
#  'Ben_Mulock',
#  'BertinetKitchen',
#  'Bosleypatch',
#  'BristolBites',
#  'BritAsparagus',
#  'BriteUK',
#  'BurtsChips',
#  'CaptGreybeard',
#  'CartmelSticky',
#  'CharlesYap',
#  'Chocoralie',
#  'CityJohn',
#  'CorkEveningEcho',
#  'CraneTV',
#  'CriticalCouple',
#  'CrumbsMag',
#  'DFergPR',
#  'DineHard',
#  'DoktorG',
#  'DominiqueAnsel',
#  'EastVillageLDN',
#  'Eater',
#  'EatingAsia',
#  'FelicitySpector',
#  'Finelychopped',
#  'FleurDeGuerre',
#  'Food52',
#  'FoodTravelCo',
#  'FoodUrchin',
#  'Foodandthefab',
#  'GinGarden',
#  'GingerPigLtd',
#  'GizziErskine',
#  'GoSeeWrite',
#  'GuildFoodWriter',
#  'Henriettagraham',
#  '49ers',
#  'ABeckr',
#  'ASE',
#  'AdamSerwer',
#  'AlAKleine',
#  'AlanFisher',
#  'Alancumming',
#  'AlbertoNardelli',
#  'AlexKoppelman',
#  'AlexSchriver',
#  'AlyWeisman',
#  'AmbShapiro',
#  'AmberLyon',
#  'Amber__McDonald',
#  'American_Bridge',
#  'AndrewKirell',
#  'AnneBell',
#  'ArunRath',
#  'AshleyJudd',
#  'BenRothenberg',
#  'CeceliaJP',
#  'FortyDeuceTwits',
#  '4SaferInternet',
#  'AAF',
#  'AFPhq',
#  'AFinnie',
#  'AHMalcolm',
#  'AaronBlakeWP',
#  'AaronMcCready',
#  'Aarongorn',
#  'AlanJSanders',
#  'AlexConant',
#  'AliBrown',
#  'AliceLinahan',
#  'AllenWest',
#  'AmandaCookWSB',
#  'AmericasRight',
#  'AndrewCMcCarthy',
#  '99forever',
#  'Bix_Barton_SW6',
#  'Claudia05SV',
#  'Dinalli',
#  'Drivin4Pleasure',
#  'EJVISO',
#  'EliGP',
#  'EmBuxton',
#  'FakeDelRosario',
#  'FakeFernando',
#  'FakeMedicalCar',
#  'FakeTomita',
#  'GARSIDEK',
#  'GP2_Official',
#  'GP3_Official',
#  'GrandPrixDiary',
#  'IamLewis4fake',
#  'JacquesDebris',
#  'Jalopnik',
#  'Just_AP',
#  'LeighOGorman',
#  'LewisFranck',
#  'LordHumphreys',
#  'MauriceHamilton',
#  'MaxGraham',
#  'Mikeconway26',
#  'OfficialMinis',
#  'PippaMann',
#  'RacingLight',
#  'RyanEversley',
#  '4AllSurfaces',
#  '5livetennis',
#  'A_Gallivant',
#  'Adamdbain',
#  'Ataraxis00',
#  'BadToss',
#  'BreakPointBR',
#  'ByJoeFleming',
#  'ChrisSkelton87',
#  'DjFlowe',
#  'ESPNTennis',
#  'EleVenbyVenus',
#  'FitLen',
#  'G2H_95',
#  'GBtennis',
#  'JLR78',
#  'JamesLaRosa',
#  'JayJarrahi',
#  'Jonirja',
#  'Kamakshi_Tandon',
#  'LeTenisse',
#  'MallerMarcelo',
#  'MendezVega',
#  'MindTheRacket',
#  'MungoNGus',
#  'NYTSports',
#  'NailaJeanMeyers',
#  'Nic_Leigh',
#  'Pep_Guti',
#  'RD_Tennistalk',
#  'Ratazana',
#  'ReemAbulleil',
#  'RoadtoRG',
#  'RomiCvitkovic',
#  'Rossana_Capo',
#  'SI_BTBaseline',
#  'SavannahsTennis',
#  'StephintheUS',
#  'TennisCoconut',
#  'Tennis_Belgium',
#  'Tennisfan24',
#  'TheBigLead',
#  'TheBoiledEgg',
#  'TheGrandSlams',
#  'TheShiftyShadow',
#  'AlisonAgosti',
#  'BenRiceM',
#  'BodyofBreen',
#  'Clarko',
#  'DadBoner',
#  'DavidWondrich',
#  'EamonLeonard',
#  'FeinsandNYDN',
#  'Heilemann',
#  'JasonNark',
#  'JimGaffigan',
#  'KeithOlbermann',
#  'MacSparky',
#  'MikeWho',
#  'PolarBearFarm',
#  'RubenBolling',
#  'SweatingCommas',
#  'TheProdigalFool',
#  'andybudd',
#  'antichrista',
#  'askvirginia',
#  'aza',
#  'baseball_ref',
#  'billba',
#  'caseyliss',
#  'cbarrett',
#  'chartier',
#  'cjse',
#  'comex',
#  'ctp',
#  'danielpunkass',
#  'dansdata',
#  'davedelong',
#  'dermdaly',
#  'dlpasco',
#  'dozba',
#  'drbarnard',
#  'drdrang',
#  'dwiskus',
#  'fchimero',
#  'gregminton',
#  'halfliterate']

# %%
user = "ACLU"
startAt = 100
tweetCount = 100

# %%
endAt = startAt + tweetCount
uid   = users.index(user)
uid
# Out:
# 0

# %%
userTweets = np.squeeze(np.asarray(np.where(X[:,uid] == 1)[0]))

startAt = min(startAt,len(userTweets))
endAt   = min(endAt,len(userTweets))
len(userTweets)
# Out:
# 927

# %%
dist[userTweets[startAt:endAt],:].shape
# Out:
# (100, 30)

# %%
fig, ax = plt.subplots(figsize=(10,10))

im = plt.imshow(dist[userTweets[startAt:endAt],:], interpolation="none")

cb = fig.colorbar(im, ax=ax)
ax.set_title(user + " Means Matrix")

# %% [markdown]
# ### Mean of User Means

# %%
userMean = dist[userTweets,:].mean(axis=0)

fig, ax = plt.subplots(figsize=(10,3))

im = plt.imshow(userMean.reshape((1, len(distMean))), interpolation="none")

cb = fig.colorbar(im, ax=ax)
ax.set_title("Mean of " + user + " topics")

# %% [markdown]
# ### Covariance of User Means

# %%
userCov = np.cov(dist[userTweets,:].T)

fig, ax = plt.subplots(figsize=(11,9))

im = plt.imshow(userCov, interpolation="none")

cb = fig.colorbar(im, ax=ax)
ax.set_title("Covariance Matrix for " + user)

# %% [markdown]
# ### Individual Tweets

# %%
def printTweet(offset):
    utid = startAt + offset
    print(",".join("%2d" % perc for perc in (dist[userTweets[utid]] * 100).astype(np.int32)))
    print ("\n".join ( dic[wid] for wid in W[userTweets[utid],:].indices ))

# %%
printTweet(73)
# Out:
#  1, 1, 1, 2, 1,17, 1, 1,17, 1, 2,10, 3, 1, 3, 2, 1, 1, 1, 2, 4, 1, 2, 2, 1, 2, 1, 2, 1, 2
# aclu
# uphold
# busi
# #billofrights
# new
# lawsuit
# grand
# polic
# urg
# be
# arrest
# properti
# rapid

# %% [markdown]
# ### Matching Topics to Tweeters

# %%
tweetAuthors = np.argmax(X[:,0:len(users) - 1], axis=1)
tweetAuthors = np.squeeze (np.asarray (tweetAuthors))

# %%
def printTopTweeters(topicId, minProb=0.7):
    authors = tweetAuthors[np.where(dist[:,topicId] > minProb)[0]]
    uniqAuthors = np.unique(authors)
    print("\n".join(users[uid] for uid in uniqAuthors))
    
printTopTweeters(topicId=5, minProb=0.6)
# Out:
# ACLU
# AdvocatesTweets
# ConnieSchultz
# CraryAP
# DemGovs
# GOPChoice
# HuffPostPol
# IpasOrg
# NARAL
# BigJournalism
# American_Bridge
# AHMalcolm
# AaronBlakeWP
# AlanJSanders

# %% [markdown]
# ## Feature Covariance Structure

# %% [markdown]
# ### Observable Feature Covariance

# %%
fig, ax = plt.subplots(figsize=(11,9))

im = plt.imshow(model.R_A, interpolation="none")

cb = fig.colorbar(im, ax=ax)
ax.set_title("Observed Feature Covariance")

# %% [markdown]
# ### Latent Feature Covariance

# %%
fig, ax = plt.subplots(figsize=(11,9))

im = plt.imshow(model.R_Y, interpolation="none")

cb = fig.colorbar(im, ax=ax)
ax.set_title("Latent Feature Covariance")

# %% [markdown]
# ### Mapping from the Latent Space to the Observed Space

# %%
feats
# Out:
# {'author': 0, 'month_of_year': 421, 'week_of_year': 398}

# %%
numWeeks = feats['month_of_year'] - feats['week_of_year']
numMonths = X.shape[1] - feats['month_of_year']
numUserSlots = feats['author']  # not all were take as some users had no tweets or no valid tweets

# %%
feature_labels = [""] * X.shape[1]
feature_labels[0:len(users)] = users

for w in range(numWeeks):
    feature_labels[feats['week_of_year'] + w] = "Week " + str(w)
    
for m in range(numMonths):
    feature_labels[feats['month_of_year'] + m] = "Month " + str(m)

# %%
mn = model.V.mean()
sd = model.V.std()
for p in range(model.P):
    vp = model.V[p,:]
    #mn = vp.mean()
    #sd = vp.std()
    
    upr = mn + 1.64 * sd
    lwr = mn - 1.64 * sd
    
    print ("\n\nLatent Space " + str(p))
    print ("\n".join("+%-15s %5.3f" % (feature_labels[f], vp[f]) for f in np.where(vp > upr)[0] if len(feature_labels[f]) > 0))
    print ("\n".join("-%-15s %5.3f" % (feature_labels[f], vp[f]) for f in np.where(vp < lwr)[0] if len(feature_labels[f]) > 0))
# Out:
# Latent Space 0
# +ForbesWoman     0.997
# +10yearBonds     0.980
# +Aalliende       0.991
# +AlmanacBeer     0.984
# +Foodandthefab   0.981
# +PolarBearFarm   0.988
# +Week 0          0.995
# -ACLU            0.003
# -Guttmacher      0.021
# -MoreMag         0.013
# -NV_Advocates    0.016
# -AmazonKDP       0.004
# -AndyLangenkamp  0.005
# -ConistonBrewCo  0.019
# -ASE             0.004
# -AlAKleine       0.015
# -AlexKoppelman   0.000
# -AmbShapiro      0.021
# -IamLewis4fake   0.000
# -JacquesDebris   0.002
# -LewisFranck     0.024
# -5livetennis     0.025
# -aza             0.028
# -drdrang         0.029
#
#
# Latent Space 1
# +AdvocatesTweets 0.991
# +ForbesWoman     0.993
# +ATryphonides    0.990
# +4pawsbrewing    0.988
# +AliceLinahan    0.980
# +Week 15         0.993
# -ChrisCQuinn     0.017
# -DirtyWars       0.026
# -BritAsparagus   0.019
# -Greatbigrobot   0.002
# -ABeckr          0.026
# -AmbJohnBolton   0.025
# -AmberMarchand   0.028
# -AndrewCMcCarthy 0.012
# -GBtennis        0.032
# -JayJarrahi      0.014
# -RomiCvitkovic   0.014
# -halfliterate    0.002
#
#
# Latent Space 2
# +CarolynBMaloney 0.993
# +ChrisCoons      0.985
# +MoreMag         0.991
# +FirestoneWalker 0.980
# +Fake_Maldonado  0.988
# +RacingLight     0.982
# +EleVenbyVenus   0.987
# +JamesLaRosa     0.996
# +MindTheRacket   0.983
# +Rossana_Capo    0.995
# +aza             0.989
# +Week 7          0.981
# +Month 0         0.993
# -AndyLangenkamp  0.012
# -BChappatta      0.005
# -AbbeyStMartin   0.030
# -BluffersGuide   0.015
# -GizziErskine    0.030
# -AHMalcolm       0.012
# -AmeliaChasse    0.002
# -FakeFernando    0.029
# -MendezVega      0.030
# -RD_Tennistalk   0.022
# -Week 0          0.005
# -Week 21         0.014
# -Month 5         0.027
#
#
# Latent Space 3
# +GOPChoice       0.993
# +Blackhorse      0.989
# +3RiversBrewery  0.997
# +ArgusBrewery    0.996
# +BHB_brews       0.999
# +DineHard        0.984
# +Week 5          0.988
# -CecileRichards  0.012
# -LatinoUSA       0.020
# -Lizchadderdon   0.020
# -FilmCritHULK    0.011
# -Ayngelina       0.012
# -MP4_28Evil      0.007
# -Clarko          0.021
# -DavidWondrich   0.025
# -JimGaffigan     0.001
# -MacSparky       0.005
#
#
# Latent Space 4
# +BobHerbert      0.999
# +CraryAP         0.980
# +Lizchadderdon   0.983
# +MHarrisPerry    0.986
# +AristidesHatzis 0.993
# +BChappatta      0.994
# +BluffersGuide   0.990
# +Food52          0.984
# +AFinnie         0.991
# +Dinalli         0.989
# +FakeMedicalCar  0.995
# +DjFlowe         0.990
# +TheShiftyShadow 0.994
# -DCAbortionFund  0.016
# -GovMarkDayton   0.025
# -HiltonHollis    0.018
# -ATryphonides    0.017
# -BlackRaven999   0.027
# -BeerAdvocate    0.023
# -Dryhopchicago   0.004
# -FullCircleBrews 0.028
# -Ayngelina       0.030
# -BriteUK         0.004
# -AlexConant      0.026
# -AmbJohnBolton   0.016
# -FakeFernando    0.018
# -Pep_Guti        0.028
# -Tennis_Belgium  0.033
# -Tennisfan24     0.026
# -chartier        0.018
# -dermdaly        0.026
#
#
# Latent Space 5
# +HeyPP           0.998
# +AmbassadorRoos  0.996
# +Blackhorse      0.987
# +3_News          0.990
# +AHMalcolm       0.980
# +OfficialMinis   0.987
# +JayJarrahi      0.986
# +antichrista     0.982
# -Beyerstein      0.022
# -ChrisMurphyCT   0.013
# -FamilyCircle    0.002
# -AlmanacBeer     0.024
# -BrianIsBeering  0.014
# -AlexSchriver    0.009
# -AFPhq           0.023
# -AaronBlakeWP    0.002
# -Anderson33      0.027
# -LewisFranck     0.007
# -TennisCoconut   0.001
# -aza             0.008
#
#
# Latent Space 6
# +AndyLangenkamp  0.986
# +BUphamT         0.989
# +FilmCritHULK    0.996
# +DFergPR         0.989
# +AshleyJudd      0.987
# +BenRothenberg   0.989
# +NailaJeanMeyers 0.983
# +Tennisfan24     0.999
# +dlpasco         0.989
# -AskDrRuth       0.022
# -CraryAP         0.000
# -HeyPP           0.028
# -A_F             0.011
# -AztecOptions    0.018
# -BirchCreekCap   0.033
# -EvelynRusli     0.010
# -Beertographer   0.033
# -5livetennis     0.008
# -TheProdigalFool 0.006
#
#
# Latent Space 7
# +CraryAP         0.982
# +AbbeyStMartin   0.995
# +BreckBrew       0.982
# +CorkEveningEcho 0.986
# +AmericasRight   0.995
# +Nic_Leigh       0.985
# +DadBoner        0.982
# -ErinMcPike      0.016
# -GOPChoice       0.022
# -AnarchyBrewCo   0.019
# -BeerAdvocate    0.019
# -Bierschenke     0.030
# -BriteUK         0.012
# -BurtsChips      0.004
# -AlyWeisman      0.025
# -GrandPrixDiary  0.005
# -ReemAbulleil    0.004
# -BodyofBreen     0.016
# -Week 3          0.015
# -Week 13         0.031
#
#
# Latent Space 8
# +AmbassadorRoos  0.987
# +AnastasiadesCY  0.989
# +Gordon_Biersch  0.995
# +BristolBites    0.981
# +MP4_28Evil      0.999
# +andybudd        0.994
# -Beyerstein      0.001
# -MoreMag         0.020
# -AlexAkesson     0.028
# -BDAmerica       0.024
# -BigJournalism   0.017
# -Beertographer   0.025
# -Beergenie       0.030
# -EatingAsia      0.002
# -GARSIDEK        0.015
# -AlisonAgosti    0.019
# -KeithOlbermann  0.026
# -Month 3         0.004
#
#
# Latent Space 9
# +DCAbortionFund  0.987
# +CraneTV         0.986
# +AaronBlakeWP    0.991
# +AndrewCMcCarthy 0.992
# +MaxGraham       0.983
# +baseball_ref    0.982
# +chartier        0.983
# -Ananicolaci     0.023
# -gte             0.018
# -Beertographer   0.000
# -BreckBrew       0.025
# -DukesJoint      0.009
# -FoodTravelCo    0.011
# -GuildFoodWriter 0.031
# -AlexKoppelman   0.020
# -AlexSkatell     0.003
# -Adamdbain       0.026
# -Pep_Guti        0.031
# -TheGrandSlams   0.019
#
#
# Latent Space 10
# +ForbesWoman     0.981
# +BLNCruzer       0.982
# +gte             0.998
# +FallCreekWines  0.991
# +FiremansBrew    0.980
# +JamesLaRosa     0.990
# -CraryAP         0.014
# -AcrossTheCurve  0.004
# -BUphamT         0.027
# -BrewEngland     0.030
# -Goats_Udder     0.025
# -AlyWeisman      0.011
# -AHMalcolm       0.024
# -AllenWest       0.023
# -MungoNGus       0.014
# -Tennis_Belgium  0.029
# -andybudd        0.023
# -antichrista     0.009
# -halfliterate    0.017
# -Week 21         0.010
#
#
# Latent Space 11
# +GovMarkDayton   0.993
# +Lizchadderdon   0.986
# +NV_Advocates    0.983
# +ATryphonides    0.992
# +GP3_Official    0.995
# +LewisFranck     1.000
# +Kamakshi_Tandon 0.981
# -FAPPA           0.024
# -LatinoUSA       0.013
# -AndreaHotter    0.007
# -RollingStones   0.024
# -AbbeyStMartin   0.028
# -BeerAndSoulBlog 0.018
# -FGW             0.024
# -FirestoneWalker 0.008
# -BertinetKitchen 0.021
# -FelicitySpector 0.000
# -AnitaSpadaro    0.025
# -4AllSurfaces    0.005
# -Month 0         0.010
#
#
# Latent Space 12
# +FleurDeGuerre   0.985
# +AmeliaChasse    0.997
# +ESPNTennis      0.999
# +Week 7          0.999
# -MHarrisPerry    0.020
# -MaryKayHenry    0.016
# -Aalliende       0.021
# -ArranBrewery    0.029
# -Ayngelina       0.017
# -CaptGreybeard   0.026
# -Amber__McDonald 0.031
# -CeceliaJP       0.023
# -AlanJSanders    0.031
# -AmericasRight   0.019
# -Bix_Barton_SW6  0.027
# -DjFlowe         0.023
#
#
# Latent Space 13
# +ABWashBureau    0.994
# +AndyHarless     0.983
# +AAF             0.984
# +MaxGraham       0.990
# +Tennisfan24     0.987
# -ChrisCQuinn     0.017
# -ForbesWoman     0.012
# -GovMarkDayton   0.010
# -BreckBrew       0.001
# -ConistonBrewCo  0.015
# -DueSouthBrewing 0.031
# -BriteUK         0.007
# -CaptGreybeard   0.031
# -CraneTV         0.018
# -EastVillageLDN  0.013
# -AlanFisher      0.012
# -Amber__McDonald 0.021
# -American_Bridge 0.005
# -FortyDeuceTwits 0.008
# -EmBuxton        0.024
# -ByJoeFleming    0.012
# -Nic_Leigh       0.012
# -JasonNark       0.027
# -Week 17         0.016
#
#
# Latent Space 14
# +DFDband         0.994
# +GingerPigLtd    0.980
# +ABeckr          0.980
# +AFinnie         0.981
# +AmandaCookWSB   0.992
# +A_Gallivant     0.989
# +caseyliss       0.987
# +ctp             0.996
# +dlpasco         0.999
# -CecileRichards  0.025
# -MaxKaminCross   0.031
# -ArranBrewery    0.032
# -DailyBeerNews   0.026
# -FiremansBrew    0.015
# -FirestoneWalker 0.017
# -BBCGoodFoodShow 0.017
# -FoodUrchin      0.030
# -AmbJohnBolton   0.006
# -JacquesDebris   0.025
# -SI_BTBaseline   0.011
# -EamonLeonard    0.030
# -Week 1          0.013
# -Week 6          0.002
# -Week 11         0.001
#
#
# Latent Space 15
# +CarolynBMaloney 0.990
# +AndreaHotter    0.999
# +Dryhopchicago   0.998
# +GarrisonBrewing 0.988
# +CraneTV         0.988
# +AmericanAir     0.983
# +Aarongorn       0.989
# +AmberMarchand   0.997
# +BreakPointBR    0.985
# +Week 6          0.991
# -FrankLautenberg 0.008
# -APStylebook     0.026
# -AnastasiadesCY  0.012
# -BritAsparagus   0.000
# -FleurDeGuerre   0.007
# -AllenWest       0.009
# -AmandaCookWSB   0.011
# -AmandaJoFreel   0.023
# -GBtennis        0.008
# -TheProdigalFool 0.026
# -davedelong      0.028
#
#
# Latent Space 16
# +BDAmerica       0.993
# +BeingRegulated  0.989
# +4pawsbrewing    0.999
# +Goats_Udder     0.981
# +CorkEveningEcho 0.983
# +AllenWest       0.980
# +GrandPrixDiary  0.997
# +Kamakshi_Tandon 0.999
# +DavidWondrich   0.983
# +RubenBolling    1.000
# -ChrisCoons      0.013
# -ConnieSchultz   0.013
# -APStylebook     0.015
# -AkronsBobert    0.032
# -EvelynRusli     0.021
# -BeerUnion       0.018
# -FullCircleBrews 0.026
# -BBCGoodFoodShow 0.012
# -BurtsChips      0.032
# -CaptGreybeard   0.020
# -EastVillageLDN  0.028
# -Dinalli         0.001
# -IamLewis4fake   0.018
# -MaxGraham       0.004
# -Ataraxis00      0.022
# -Week 21         0.020
#
#
# Latent Space 17
# +10yearBonds     0.987
# +DominiqueAnsel  0.981
# +Nic_Leigh       0.996
# +Week 10         0.984
# -Beyerstein      0.024
# -DemGovs         0.008
# -LatinoUSA       0.031
# -AnastasiadesCY  0.009
# -ArgusBrewery    0.018
# -ArranBrewery    0.021
# -BurtsChips      0.010
# -ACLINews        0.020
# -AlexSchriver    0.016
# -AndrewKirell    0.031
# -AmeliaChasse    0.009
# -Claudia05SV     0.032
# -EliGP           0.009
# -NYTSports       0.013
# -andybudd        0.019
# -Month 2         0.000
# -Month 4         0.001
# -Month 5         0.023
#
#
# Latent Space 18
# +MaryKayHenry    0.999
# +AGonzalezAquino 0.981
# +AlanFisher      0.993
# +RoadtoRG        0.991
# +ctp             0.990
# +Week 10         0.995
# -EHobbz          0.026
# -FiremansBrew    0.022
# -EleVenbyVenus   0.018
# -G2H_95          0.009
#
#
# Latent Space 19
# +AlexAkesson     0.998
# +CraftingANation 0.993
# +BertinetKitchen 0.992
# +AskAkbar        0.994
# +AmbJohnBolton   0.992
# +AustinGrandPrix 0.989
# +Fake_Maldonado  0.991
# +LeTenisse       0.989
# +Tennis_Belgium  0.982
# -AskDrRuth       0.023
# -ChrisCQuinn     0.007
# -DrNancyNBCNEWS  0.022
# -Ayngelina       0.003
# -AAF             0.005
# -EliGP           0.009
# -JacquesDebris   0.015
# -RubenBolling    0.015
# -dwiskus         0.011
#
#
# Latent Space 20
# +A_F             0.981
# +BLNCruzer       0.988
# +AlanJSanders    0.998
# +DavidWondrich   0.994
# -BigBlueTent     0.013
# -BeerAdvocate    0.020
# -ConistonBrewCo  0.003
# -CraftingANation 0.000
# -FallCreekWines  0.002
# -3_News          0.007
# -BertinetKitchen 0.016
# -Foodandthefab   0.008
# -GizziErskine    0.017
# -AlanFisher      0.001
# -PippaMann       0.004
# -EleVenbyVenus   0.022
# -SI_BTBaseline   0.030
# -Week 1          0.024
#
#
# Latent Space 21
# +HadleyFreeman   1.000
# +AztecOptions    0.993
# +BenRothenberg   0.980
# +AmericasRight   0.985
# +Adamdbain       0.989
# +Ratazana        0.998
# +KeithOlbermann  0.994
# -ACLU            0.006
# -NV_Advocates    0.001
# -AlphaVN         0.012
# -Gary_Bainbridge 0.000
# -CityJohn        0.027
# -GizziErskine    0.006
# -JLR78           0.001
# -Week 12         0.014
#
#
# Latent Space 22
# +ChrisCoons      0.999
# +Blackhorse      0.988
# +ArgusBrewery    1.000
# +FoodTravelCo    0.990
# +AlexisGelber    0.989
# +CeceliaJP       0.994
# +AaronBlakeWP    0.993
# +AllenWest       0.984
# +gregminton      0.995
# +Week 1          0.993
# +Week 14         0.995
# -ErinMcPike      0.022
# -5_min_macro     0.027
# -Aalliende       0.010
# -AmazonKDP       0.028
# -Annika_Reuters  0.027
# -DFDband         0.010
# -BritAsparagus   0.024
# -49ers           0.025
# -AmbJohnBolton   0.014
# -99forever       0.032
# -EliGP           0.012
# -5livetennis     0.005
# -Adamdbain       0.018
# -aza             0.025
#
#
# Latent Space 23
# +ArgusBrewery    0.994
# +FakeDelRosario  0.998
# +Ataraxis00      0.980
# +BadToss         0.984
# +KeithOlbermann  0.993
# -ChrisMurphyCT   0.013
# -benschott       0.011
# -5_min_macro     0.004
# -BeerUnion       0.018
# -BullCityBurger  0.021
# -FiremansBrew    0.029
# -AmyDavies       0.019
# -FoodUrchin      0.004
# -GrandPrixDiary  0.022
# -JLR78           0.022
# -ctp             0.016
# -Week 15         0.003
# -Month 4         0.022
#
#
# Latent Space 24
# +Ananicolaci     0.991
# +FGW             0.994
# +BadToss         0.983
# +Jonirja         0.990
# +antichrista     0.990
# +baseball_ref    0.990
# -ABWashBureau    0.006
# -3RiversBrewery  0.009
# -Bierschenke     0.001
# -BreckBrew       0.030
# -GarrisonBrewing 0.016
# -GP2_Official    0.003
# -MP4_28Evil      0.015
# -PippaMann       0.008
# -SavannahsTennis 0.027
# -Week 1          0.028
# -Week 6          0.027
# -Week 10         0.026
#
#
# Latent Space 25
# +ACLU            0.982
# +CromartyBrewing 0.998
# +FelicitySpector 0.995
# +FleurDeGuerre   0.981
# +GinGarden       0.998
# +MungoNGus       0.991
# +Week 8          0.986
# -AnnRichardsPlay 0.007
# -BabatundeUNFPA  0.013
# -FriendsofUNFPA  0.019
# -4Tanguay        0.008
# -AkronsBobert    0.024
# -Benzinga        0.014
# -BirchCreekCap   0.024
# -DirtyWars       0.013
# -FirestoneWalker 0.001
# -AmberLyon       0.007
# -GP2_Official    0.011
# -NYTSports       0.032
# -RomiCvitkovic   0.010
# -TheBigLead      0.032
# -BenRiceM        0.028
# -DavidWondrich   0.008
# -KeithOlbermann  0.024
# -billba          0.021
# -chartier        0.009
#
#
# Latent Space 26
# +CecileRichards  0.996
# +MoreMag         0.986
# +NV_Advocates    0.988
# +Benzinga        0.985
# +BirchCreekCap   0.997
# +CromartyBrewing 0.985
# +GuildFoodWriter 0.987
# +AmberMarchand   0.994
# +Kamakshi_Tandon 0.986
# +Month 1         0.996
# -ErinMcPike      0.032
# -AlphaVN         0.024
# -AGonzalezAquino 0.013
# -AmericanAir     0.004
# -AHMalcolm       0.005
# -BadToss         0.012
# -MungoNGus       0.030
# -Nic_Leigh       0.027
# -Pep_Guti        0.011
# -SI_BTBaseline   0.021
# -DadBoner        0.005
#
#
# Latent Space 27
# +CarolynBMaloney 0.996
# +FirestoneWalker 0.981
# +AnneBell        0.994
# +MaxGraham       0.999
# +MungoNGus       0.988
# -AdvocatesTweets 0.023
# -BabatundeUNFPA  0.032
# -ChrisCoons      0.027
# -AkronsBobert    0.003
# -AnastasiadesCY  0.027
# -Brewery85       0.009
# -ConistonBrewCo  0.010
# -ForumBooks      0.006
# -AmyDavies       0.031
# -CharlesYap      0.027
# -EatingAsia      0.010
# -AmbJohnBolton   0.024
# -Dinalli         0.024
# -GP3_Official    0.012
# -StephintheUS    0.030
# -TheProdigalFool 0.018
#
#
# Latent Space 28
# +ErinMcPike      0.982
# +FriendsofUNFPA  0.993
# +247WallSt       0.985
# +BrewDogBarDean  0.992
# +AdamSerwer      0.991
# +AliBrown        0.999
# +Ratazana        0.992
# +DavidWondrich   0.987
# -CLPPtweets      0.018
# -Lizchadderdon   0.016
# -BlueBellHalkyn  0.031
# -DFDband         0.002
# -CriticalCouple  0.029
# -CrumbsMag       0.029
# -AlAKleine       0.006
# -AAF             0.011
# -AlexConant      0.031
# -AliceLinahan    0.019
# -FakeTomita      0.023
# -LeighOGorman    0.025
# -cjse            0.029
# -comex           0.011
#
#
# Latent Space 29
# +ForbesWoman     0.981
# +Alan_Duerden    0.982
# +BChappatta      0.982
# +2lovebeer       0.984
# +BeerBods        0.996
# +FallCreekWines  0.998
# +DoktorG         0.993
# +AlanFisher      0.993
# +JacquesDebris   0.997
# +LordHumphreys   0.989
# +Adamdbain       0.986
# +FitLen          0.983
# +TheShiftyShadow 0.988
# +JimGaffigan     0.996
# +baseball_ref    0.981
# +ctp             0.984
# -ChrisMurphyCT   0.026
# -HuffPostPol     0.009
# -Aalliende       0.004
# -Annika_Reuters  0.020
# -BDAmerica       0.017
# -FelicitySpector 0.002
# -49ers           0.000
# -AliBrown        0.001
# -AmericasRight   0.023
# -GP2_Official    0.030
# -LeighOGorman    0.005
# -ReemAbulleil    0.008
# -Heilemann       0.007
# -comex           0.013
# -drbarnard       0.032
# -Week 17         0.013
# -Month 3         0.004

# %%
st = "sd/f"

# %%
st.replace('/','_')
# Out:
# 'sd_f'

# %%
import time

# %%
time.gmtime?

# %%
time.strftime("%Y%m%d-%H%M", time.gmtime())
# Out:
# '20140218-2131'

# %%
time.strftime?

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-113-e7addf085a78> in <module>()
# ----> 1 P in model
#
# NameError: name 'P' is not defined
